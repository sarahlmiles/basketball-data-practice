# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahlmiles/basketball-data-practice/blob/main/basketball_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello basketball!")
# Out:
# Hello basketball!
